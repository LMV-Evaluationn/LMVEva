# %%
#Proyecto Tendencia e Innovación en Tecnología Agrícola

# %%
import  pandas as pd

# %%
DatosTea =pd.read_csv("DatosTea.csv")

# %%
DatosTea
# Out:
#     Código Ámbito                     Ámbito  Código área (M49)         Área  \
# 0              EM  Distribución de emisiones                222  El Salvador
# 1              EM  Distribución de emisiones                222  El Salvador
# 2              EM  Distribución de emisiones                222  El Salvador
# 3              EM  Distribución de emisiones                222  El Salvador
# 4              EM  Distribución de emisiones                222  El Salvador
# ..            ...                        ...                ...          ...
# 235            EM  Distribución de emisiones                558    Nicaragua
# 236            EM  Distribución de emisiones                558    Nicaragua
# 237            EM  Distribución de emisiones                558    Nicaragua
# 238            EM  Distribución de emisiones                558    Nicaragua
# 239            EM  Distribución de emisiones                558    Nicaragua
#
# ...

# %%
honduras= DatosTea[DatosTea.Área == "Honduras"]

# %%
honduras
# Out:
#     Código Ámbito                     Ámbito  Código área (M49)      Área  \
# 120            EM  Distribución de emisiones                340  Honduras
# 121            EM  Distribución de emisiones                340  Honduras
# 122            EM  Distribución de emisiones                340  Honduras
# 123            EM  Distribución de emisiones                340  Honduras
# 124            EM  Distribución de emisiones                340  Honduras
# 125            EM  Distribución de emisiones                340  Honduras
# 126            EM  Distribución de emisiones                340  Honduras
# 127            EM  Distribución de emisiones                340  Honduras
# 128            EM  Distribución de emisiones                340  Honduras
# 129            EM  Distribución de emisiones                340  Honduras
# 130            EM  Distribución de emisiones                340  Honduras
# 131            EM  Distribución de emisiones                340  Honduras
# ...

# %%
nicaragua= DatosTea[DatosTea.Área == "Nicaragua"]

# %%
nicaragua
# Out:
#     Código Ámbito                     Ámbito  Código área (M49)       Área  \
# 180            EM  Distribución de emisiones                558  Nicaragua
# 181            EM  Distribución de emisiones                558  Nicaragua
# 182            EM  Distribución de emisiones                558  Nicaragua
# 183            EM  Distribución de emisiones                558  Nicaragua
# 184            EM  Distribución de emisiones                558  Nicaragua
# 185            EM  Distribución de emisiones                558  Nicaragua
# 186            EM  Distribución de emisiones                558  Nicaragua
# 187            EM  Distribución de emisiones                558  Nicaragua
# 188            EM  Distribución de emisiones                558  Nicaragua
# 189            EM  Distribución de emisiones                558  Nicaragua
# 190            EM  Distribución de emisiones                558  Nicaragua
# ...

# %%
# Comparación entre Honduras y Nicaragua para determinar que país emite más GEI

# %%
from matplotlib import pyplot as plt

# %%
honduras = DatosTea [DatosTea.Área == "Honduras"]
nicaragua = DatosTea [DatosTea.Área == "Nicaragua"]

# %%
plt.plot (honduras.Año, honduras.Valor, color="green", linewidth=4, linestyle="-")
plt.plot (nicaragua.Año, nicaragua.Valor,color="orange", linewidth=4, linestyle="-")
plt.xlabel ("Años",fontsize=13)
plt.ylabel ("valores",fontsize=13)
plt.title("Distribución de Emisiones",fontsize=15,color="red")
plt.legend(["Honduras","Nicaragua"])
plt.show()

# %%
# Comparación entre Honduras y El Salvador para determinar que país emite más GEI

# %%
honduras = DatosTea [DatosTea.Área == "Honduras"]
guatemala = DatosTea [DatosTea.Área == "Guatemala"]

# %%
plt.plot (honduras.Año, honduras.Valor, color="green", linewidth=4, linestyle="-")
plt.plot (guatemala.Año, guatemala.Valor,color="blue", linewidth=4, linestyle="-")
plt.xlabel ("Años",fontsize=13)
plt.ylabel ("valores",fontsize=13)
plt.title("Distribución de Emisiones",fontsize=15,color="red")
plt.legend(["Honduras","Guatemala"])
plt.show()

# %%
# Comparación entre Honduras y El Salvador para determinar que país emite más GEI

# %%
honduras = DatosTea [DatosTea.Área == "Honduras"]
salvador = DatosTea [DatosTea.Área == "El Salvador"]

# %%
plt.plot (honduras.Año, honduras.Valor, color="green", linewidth=4, linestyle="-")
plt.plot (salvador.Año, salvador.Valor,color="yellow", linewidth=4, linestyle="-")
plt.xlabel ("Años",fontsize=13)
plt.ylabel ("valores",fontsize=13)
plt.title("Distribución de Emisiones",fontsize=15,color="red")
plt.legend(["Honduras","El Salvador"])
plt.show()
